# %%
import pandas as pd
from __future__ import unicode_literals
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_excel('Copy of Book2(1382).xlsx')
df
# Out:
#                             ยศ - ชื่อ วุฒิการบิน  คะแนน  ฝูง
# 0               น.ท.วิทวัส  ปวัฒพันธ์        คบ.     96  601
# 1             น.ต.ภัทร์กฤต  ดิษฐบรรจง        คบ.     93  601
# 2                 น.ต.ญาณพจน์  คำตั๋น        คบ.     99  601
# 3               น.ต.เอกนัย  ภูวังหม้อ        คบ.     96  601
# 4                    น.ต.ถาวร  กิมทอง        คบ.     98  601
# ..                                ...        ...    ...  ...
# 95  ร.ต.หญิง ศุภางค์  เติมศักดิ์เจริญ     นบ.ว.๓     88  604
# 96      ร.ต.หญิง ฐิศิรักน์  เทียนเกษม     นบ.ว.๓     96  604
# 97               น.ต.ณัฐพล  รุ่งเรือง        คบ.     98  604
# 98             ร.อ.ธนากร  นิธิภัทรวุธ        คบ.     95  604
# 99                 ร.อ.เมธี  มีขันทอง     นบ.ว.๓     94  604
#
# [100 rows x 4 columns]

# %%
df.groupby(['ฝูง'])['คะแนน'].describe()
# Out:
#      count       mean       std   min   25%   50%     75%    max
# ฝูง
# 601   32.0  95.156250  2.244842  88.0  94.0  95.0   96.25  100.0
# 602   29.0  95.206897  1.934265  91.0  94.0  95.0   96.00   99.0
# 603   17.0  98.588235  1.175735  97.0  98.0  99.0  100.00  100.0
# 604   22.0  92.090909  3.650298  85.0  91.0  92.5   94.00   98.0

# %%
df.describe()
# Out:
#            คะแนน         ฝูง
# count  100.00000  100.000000
# mean    95.08000  602.290000
# std      3.12914    1.139688
# min     85.00000  601.000000
# 25%     94.00000  601.000000
# 50%     95.00000  602.000000
# 75%     97.00000  603.000000
# max    100.00000  604.000000

# %%
plt.rcParams['font.family']= 'Tahoma'
plt.rcParams['font.size'] = 20
plt.figure(figsize = (10,7))
sns.boxplot(x= 'ฝูง' , y = 'คะแนน' , data = df);
plt.title('คะแนนสอบวิชาการ บน.๖')
avg = df['คะแนน'].mean()
plt.axhline(y=avg, linestyle = '--', color = 'red')
